# %% [markdown]
# Note: Data is from the UCI Machine Learning Repository:
#
# Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.

# %% [markdown]
# - age: age in years
# - sex: 1=male, 0=female
# - cp: chest pain type
#  - Value 1: typical angina
#  - Value 2: atypical angina
#  - Value 3: non-anginal pain
#  - Value 4: asymptomatic
# - trestbps: resting blood pressure (in mm Hg on admission to the hospital)
# - chol: serum cholestoral in mg/dl
# - fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# - restecg: resting electrocardiographic results
#  - Value 0: normal
#  - Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#  - Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
# - thalach: maximum heart rate achieved in an exercise test
# - exang: exercise induced angina (1 = yes; 0 = no)
# - oldpeak: ST depression induced by exercise relative to rest
# - slope: the slope of the peak exercise ST segment
#  - Value 1: upsloping
#  - Value 2: flat
#  - Value 3: downsloping
# - ca: number of major vessels (0-3) colored by flourosopy
# - thal:
#  - Value 3: normal
#  - Value 6: fixed defect
#  - Value 7: reversable defect
# - heart_disease: diagnosis of heart disease (angiographic disease status)
#  - Value 0: < 50% diameter narrowing
#  - Value 1: > 50% diameter narrowing
# "\[This field\] refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4. Experiments with the Cleveland database have concentrated on simply attempting to distinguish presence (values 1,2,3,4) from absence (value 0)."

# %%
heart.head(50)
# Out:
#      age     sex                cp  trestbps   chol    fbs  restecg  thalach  \
# 0   63.0    male    typical angina     145.0  233.0   true      2.0    150.0
# 1   67.0    male      asymptomatic     160.0  286.0  false      2.0    108.0
# 2   67.0    male      asymptomatic     120.0  229.0  false      2.0    129.0
# 3   37.0    male  non-anginal pain     130.0  250.0  false      0.0    187.0
# 4   41.0  female   atypical angina     130.0  204.0  false      2.0    172.0
# 5   56.0    male   atypical angina     120.0  236.0  false      0.0    178.0
# 6   62.0  female      asymptomatic     140.0  268.0  false      2.0    160.0
# 7   57.0  female      asymptomatic     120.0  354.0  false      0.0    163.0
# 8   63.0    male      asymptomatic     130.0  254.0  false      2.0    147.0
# 9   53.0    male      asymptomatic     140.0  203.0   true      2.0    155.0
# 10  57.0    male      asymptomatic     140.0  192.0  false      0.0    148.0
# 11  56.0  female   atypical angina     140.0  294.0  false      2.0    153.0
# 12  56.0    male  non-anginal pain     130.0  256.0   true      2.0    142.0
# 13  44.0    male   atypical angina     120.0  263.0  false      0.0    173.0
# 14  52.0    male  non-anginal pain     172.0  199.0   true      0.0    162.0
# 15  57.0    male  non-anginal pain     150.0  168.0  false      0.0    174.0
# 16  48.0    male   atypical angina     110.0  229.0  false      0.0    168.0
# 17  54.0    male      asymptomatic     140.0  239.0  false      0.0    160.0
# 18  48.0  female  non-anginal pain     130.0  275.0  false      0.0    139.0
# 19  49.0    male   atypical angina     130.0  266.0  false      0.0    171.0
# 20  64.0    male    typical angina     110.0  211.0  false      2.0    144.0
# 21  58.0  female    typical angina     150.0  283.0   true      2.0    162.0
# 22  58.0    male   atypical angina     120.0  284.0  false      2.0    160.0
# 23  58.0    male  non-anginal pain     132.0  224.0  false      2.0    173.0
# 24  60.0    male      asymptomatic     130.0  206.0  false      2.0    132.0
# 25  50.0  female  non-anginal pain     120.0  219.0  false      0.0    158.0
# 26  58.0  female  non-anginal pain     120.0  340.0  false      0.0    172.0
# 27  66.0  female    typical angina     150.0  226.0  false      0.0    114.0
# 28  43.0    male      asymptomatic     150.0  247.0  false      0.0    171.0
# 29  40.0    male      asymptomatic     110.0  167.0  false      2.0    114.0
# 30  69.0  female    typical angina     140.0  239.0  false      0.0    151.0
# 31  60.0    male      asymptomatic     117.0  230.0   true      0.0    160.0
# 32  64.0    male  non-anginal pain     140.0  335.0  false      0.0    158.0
# 33  59.0    male      asymptomatic     135.0  234.0  false      0.0    161.0
# 34  44.0    male  non-anginal pain     130.0  233.0  false      0.0    179.0
# 35  42.0    male      asymptomatic     140.0  226.0  false      0.0    178.0
# 36  43.0    male      asymptomatic     120.0  177.0  false      2.0    120.0
# 37  57.0    male      asymptomatic     150.0  276.0  false      2.0    112.0
# 38  55.0    male      asymptomatic     132.0  353.0  false      0.0    132.0
# 39  61.0    male  non-anginal pain     150.0  243.0   true      0.0    137.0
# 40  65.0  female      asymptomatic     150.0  225.0  false      2.0    114.0
# 41  40.0    male    typical angina     140.0  199.0  false      0.0    178.0
# 42  71.0  female   atypical angina     160.0  302.0  false      0.0    162.0
# 43  59.0    male  non-anginal pain     150.0  212.0   true      0.0    157.0
# 44  61.0  female      asymptomatic     130.0  330.0  false      2.0    169.0
# 45  58.0    male  non-anginal pain     112.0  230.0  false      2.0    165.0
# 46  51.0    male  non-anginal pain     110.0  175.0  false      0.0    123.0
# 47  50.0    male      asymptomatic     150.0  243.0  false      2.0    128.0
# 48  65.0  female  non-anginal pain     140.0  417.0   true      2.0    157.0
# 49  53.0    male  non-anginal pain     130.0  197.0   true      2.0    152.0
#
#    exang  oldpeak        slope      ca               thal heart_disease
# 0     no      2.3  downsloping      up       fixed defect       absence
# 1    yes      1.5         flat  normal             normal      presence
# 2    yes      2.6         flat    down  reversable defect      presence
# 3     no      3.5  downsloping      up             normal       absence
# 4     no      1.4    upsloping      up             normal       absence
# 5     no      0.8    upsloping      up             normal       absence
# 6     no      3.6  downsloping    down             normal      presence
# 7    yes      0.6    upsloping      up             normal       absence
# 8     no      1.4         flat    flat  reversable defect      presence
# 9    yes      3.1  downsloping      up  reversable defect      presence
# 10    no      0.4         flat      up       fixed defect       absence
# 11    no      1.3         flat      up             normal       absence
# 12   yes      0.6         flat    flat       fixed defect      presence
# 13    no      0.0    upsloping      up  reversable defect       absence
# 14    no      0.5    upsloping      up  reversable defect       absence
# 15    no      1.6    upsloping      up             normal       absence
# 16    no      1.0  downsloping      up  reversable defect      presence
# 17    no      1.2    upsloping      up             normal       absence
# 18    no      0.2    upsloping      up             normal       absence
# 19    no      0.6    upsloping      up             normal       absence
# 20   yes      1.8         flat      up             normal       absence
# 21    no      1.0    upsloping      up             normal       absence
# 22    no      1.8         flat      up             normal      presence
# 23    no      3.2    upsloping    down  reversable defect      presence
# 24   yes      2.4         flat    down  reversable defect      presence
# 25    no      1.6         flat      up             normal       absence
# 26    no      0.0    upsloping      up             normal       absence
# 27    no      2.6  downsloping      up             normal       absence
# 28    no      1.5    upsloping      up             normal       absence
# 29   yes      2.0         flat      up  reversable defect      presence
# 30    no      1.8    upsloping    down             normal       absence
# 31   yes      1.4    upsloping    down  reversable defect      presence
# 32    no      0.0    upsloping      up             normal      presence
# 33    no      0.5         flat      up  reversable defect       absence
# 34   yes      0.4    upsloping      up             normal       absence
# 35    no      0.0    upsloping      up             normal       absence
# 36   yes      2.5         flat      up  reversable defect      presence
# 37   yes      0.6         flat    flat       fixed defect      presence
# 38   yes      1.2         flat    flat  reversable defect      presence
# 39   yes      1.0         flat      up             normal       absence
# 40    no      1.0         flat  normal  reversable defect      presence
# 41   yes      1.4    upsloping      up  reversable defect       absence
# 42    no      0.4    upsloping    down             normal       absence
# 43    no      1.6    upsloping      up             normal       absence
# 44    no      0.0    upsloping      up             normal      presence
# 45    no      2.5         flat    flat  reversable defect      presence
# 46    no      0.6    upsloping      up             normal       absence
# 47    no      2.6         flat      up  reversable defect      presence
# 48    no      0.8    upsloping    flat             normal       absence
# 49    no      1.2  downsloping      up             normal       absence

# %%
# Out:
# No     164
# Yes    139
# Name: heart_disease, dtype: int64
